# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
train_df = pd.read_csv("train.csv")

# %%
test_df = pd.read_csv("test.csv")

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
train_df.describe(include = ["O"]).T
# Out:
#          count unique                  top freq
# Name       891    891  Abelson, Mr. Samuel    1
# Sex        891      2                 male  577
# Ticket     891    681               347082    7
# Cabin      204    147          C23 C25 C27    4
# Embarked   889      3                    S  644

# %%
train_df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.countplot(train_df["Sex"])
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
def category(degisken):
    print("-------------------------------------")
    print(train_df[degisken].value_counts())
    
    sns.countplot(train_df[degisken])
    plt.show()

# %%
category_list = ["Survived", "Pclass", "Sex", "SibSp", "Parch", "Embarked", "Cabin"]

for i in category_list:
    
    category(i)
# Out:
# -------------------------------------
# 0    549
# 1    342
# Name: Survived, dtype: int64
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# male      577
# female    314
# Name: Sex, dtype: int64
# ...

# %%
#numerical variable analysis
def sayisal(degisken):
    
    plt.hist(train_df[degisken], bins = 50)
    plt.xlabel(degisken)
    plt.ylabel("Frekans")
    plt.title("{} değişken dağılımı".format(degisken))
    plt.show()

# %%
sayisal_list = ["Age", "Fare", "PassengerId"]

for i in sayisal_list:
    
    sayisal(i)

# %%
#multiple analysis
train_df.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
sns.barplot(x = "Sex", y = "Survived", data = train_df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
def kategorik_etki(degisken):
    
    print("{} değişkenin survived'e etkisi : \n".format(degisken))
    print(train_df.groupby(degisken)["Survived"].mean())
    
    sns.barplot(x = degisken, y = "Survived", data = train_df)
    plt.show()

# %%
list1 = ["Pclass", "Sex", "SibSp", "Parch", "Embarked"]

for i in list1:
    
    kategorik_etki(i)
# Out:
# Pclass değişkenin survived'e etkisi :
#
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64
# Sex değişkenin survived'e etkisi :
#
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
# SibSp değişkenin survived'e etkisi :
#
# SibSp
# 0    0.345395
# 1    0.535885
# 2    0.464286
# 3    0.250000
# 4    0.166667
# 5    0.000000
# 8    0.000000
# Name: Survived, dtype: float64
# Parch değişkenin survived'e etkisi :
#
# Parch
# 0    0.343658
# 1    0.550847
# 2    0.500000
# 3    0.600000
# 4    0.000000
# 5    0.200000
# 6    0.000000
# Name: Survived, dtype: float64
# Embarked değişkenin survived'e etkisi :
#
# Embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: Survived, dtype: float64

# %%
train_df[(train_df["Sex"] == "male") & (train_df["Pclass"] == 3)]["Survived"].mean()
# Out:
# 0.13544668587896252

# %%
train_df[(train_df["Sex"] == "female") & (train_df["Pclass"] == 1)]["Survived"].mean()
# Out:
# 0.9680851063829787

# %%
train_df[(train_df["Sex"] == "male") & (train_df["Pclass"] == 1)]["Survived"].mean()
# Out:
# 0.36885245901639346

# %%
sns.barplot(x = "Cabin", y = "Survived", data = train_df) # Etkisi yok
# Out:
# <AxesSubplot:xlabel='Cabin', ylabel='Survived'>

# %%
sns.jointplot("Age", "Survived", data = train_df, kind = "reg")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("Age", "Survived", data = train_df, kind = "kde")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("Age", "Survived", data = train_df, kind = "hex")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("Fare", "Survived", data = train_df, kind = "reg")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("Fare", "Survived", data = train_df, kind = "kde")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot("Fare", "Survived", data = train_df, kind = "hex")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x = "Pclass", y = "Fare", data = train_df, hue = "Survived")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
df1 = train_df.corr()
df1
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(df1, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(train_df)

# %%
f = sns.FacetGrid(train_df, col = "Survived")
f.map(plt.hist, "Age")

# %%
f1 = sns.FacetGrid(train_df, row = "Pclass", col = "Survived")
f1.map(plt.hist, "Age", bins = 20)

# %%
f2 = sns.FacetGrid(train_df, row = "Embarked")
f2.map(sns.pointplot, "Pclass", "Survived", "Sex")
f2.add_legend()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:650: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
f3 = sns.FacetGrid(train_df, row = "Embarked", col = "Survived")
f3.map(sns.barplot, "Sex", "Fare")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#outlier detection
train_df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
def outlier(degisken):
    
    sns.boxplot(train_df[degisken])
    plt.show()

# %%
liste = ["Pclass", "Age", "SibSp", "Parch", "Fare"]

for i in liste:
    outlier(i)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
Q1 = train_df["Fare"].quantile(0.25)
Q3 = train_df["Fare"].quantile(0.75)


IQR = Q3 - Q1

alt_sinir = Q1 - 1.5*IQR
ust_sinir = Q3 + 1.5*IQR

toplam_filtre = ((train_df["Fare"] < alt_sinir) | (train_df["Fare"] > ust_sinir))

aykiri_gozlemler = train_df["Fare"][toplam_filtre]

# %%
list(aykiri_gozlemler.index)
train_df.loc[aykiri_gozlemler.index]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 846          847         0       3
# 849          850         1       1
# 856          857         1       1
# 863          864         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
def outlier(df, degiskenler):
    
    aykiri_indexler = []
    
    for i in degiskenler:
        
        Q1 = df[i].quantile(0.25)
        Q3 = df[i].quantile(0.75)


        IQR = Q3 - Q1

        alt_sinir = Q1 - 1.5*IQR
        ust_sinir = Q3 + 1.5*IQR

        toplam_filtre = ((df[i] < alt_sinir) | (df[i] > ust_sinir))

        aykiri_gozlemler = df[i][toplam_filtre]
        aykiri_index = aykiri_gozlemler.index
        
        aykiri_indexler.extend(aykiri_index)
        
    aykiri_indexler = Counter(aykiri_indexler)
    
    ortak_indexler = [i for i, v in aykiri_indexler.items() if v > 2]
    
    return ortak_indexler

# %%
ortak_indexler = outlier(train_df, ["Age", "SibSp", "Parch", "Fare"])

train_df.loc[ortak_indexler]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 745          746         0       1       Crosby, Capt. Edward Gifford    male
# 27            28         0       1     Fortune, Mr. Charles Alexander    male
# 88            89         1       1         Fortune, Miss. Mabel Helen  female
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 341          342         1       1     Fortune, Miss. Alice Elizabeth  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
# ...

# %%
train_df = train_df.drop(ortak_indexler, axis = 0).reset_index(drop = True)

train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 875          887         0       2
# 876          888         1       1
# 877          889         0       3
# 878          890         1       1
# 879          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#editing missing data 
birlesim_df = pd.concat([train_df, test_df], axis = 0).reset_index(drop = True)

birlesim_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1293         1305       NaN       3
# 1294         1306       NaN       1
# 1295         1307       NaN       3
# 1296         1308       NaN       3
# 1297         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
birlesim_df.columns[birlesim_df.isnull().any()]
# Out:
# Index(['Survived', 'Age', 'Fare', 'Cabin', 'Embarked'], dtype='object')

# %%
birlesim_df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             256
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1007
# Embarked          2
# dtype: int64

# %%
birlesim_df[birlesim_df["Fare"].isnull()]
# Out:
#       PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 1032         1044       NaN       3  Storey, Mr. Thomas  male  60.5      0
#
#       Parch Ticket  Fare Cabin Embarked
# 1032      0   3701   NaN   NaN        S

# %%
sns.boxplot(x = "Pclass", y = "Fare", data = birlesim_df, hue = "Embarked")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(x = "Pclass", y = "Fare", data = birlesim_df, hue = "Sex")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
birlesim_df.groupby(["Pclass", "Sex", "Embarked"])["Fare"].mean()
# Out:
# Pclass  Sex     Embarked
# 1       female  C           118.895949
#                 Q            90.000000
#                 S            96.235388
#         male    C            94.622560
#                 Q            90.000000
#                 S            51.532469
# 2       female  C            27.003791
#                 Q            12.350000
#                 S            23.023118
#         male    C            20.904406
#                 Q            11.489160
#                 S            20.073322
# 3       female  C            13.834545
#                 Q             9.791968
#                 S            16.858467
#         male    C             9.775901
#                 Q            10.979167
#                 S            12.521002
# Name: Fare, dtype: float64

# %%
birlesim_df["Fare"].mean()
# Out:
# 32.539427062451836

# %%
birlesim_df["Fare"].fillna(12.521002, inplace =True)

# %%
birlesim_df[birlesim_df["Fare"].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
birlesim_df[birlesim_df["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 60            62       1.0       1                        Icard, Miss. Amelie
# 820          830       1.0       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 60   female  38.0      0      0  113572  80.0   B28      NaN
# 820  female  62.0      0      0  113572  80.0   B28      NaN

# %%
sns.boxplot(x = "Embarked", y = "Fare", data = birlesim_df, hue = "Pclass")
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Fare'>

# %%
sns.boxplot(x = "Embarked", y = "Fare", data = birlesim_df, hue = "Sex")
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Fare'>

# %%
birlesim_df.groupby(["Embarked", "Sex"])["Pclass", "Fare"].mean()
# Out:
# <ipython-input-60-dc21f7f0eb83>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   birlesim_df.groupby(["Embarked", "Sex"])["Pclass", "Fare"].mean()
#                    Pclass       Fare
# Embarked Sex
# C        female  1.646018  81.128540
#          male    2.000000  48.810619
# Q        female  2.900000  12.550837
#          male    2.888889  12.273941
# S        female  2.206294  37.458349
#          male    2.414911  21.046952

# %%
birlesim_df["Embarked"].fillna("C", inplace = True)

# %%
birlesim_df[birlesim_df["Embarked"].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
birlesim_df[birlesim_df["Age"].isnull()]
# Out:
#       PassengerId  Survived  Pclass                             Name     Sex  \
# 5               6       0.0       3                 Moran, Mr. James    male
# 17             18       1.0       2     Williams, Mr. Charles Eugene    male
# 19             20       1.0       3          Masselmani, Mrs. Fatima  female
# 26             27       0.0       3          Emir, Mr. Farred Chehab    male
# 27             29       1.0       3    O'Dwyer, Miss. Ellen "Nellie"  female
# ...           ...       ...     ...                              ...     ...
# 1288         1300       NaN       3  Riordan, Miss. Johanna Hannah""  female
# 1290         1302       NaN       3           Naughton, Miss. Hannah  female
# 1293         1305       NaN       3               Spector, Mr. Woolf    male
# 1296         1308       NaN       3              Ware, Mr. Frederick    male
# 1297         1309       NaN       3         Peter, Master. Michael J    male
#
# ...

# %%
sns.factorplot(x = "Sex", y = "Age", data = birlesim_df, kind = "box")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x = "Pclass", y = "Age", data = birlesim_df, kind = "box")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x = "Parch", y = "Age", data = birlesim_df, kind = "box")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x = "SibSp", y = "Age", data = birlesim_df, kind = "box")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x = "Embarked", y = "Age", data = birlesim_df, kind = "box")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df1 = birlesim_df.corr()

sns.heatmap(df1, annot = True)
# Out:
# <AxesSubplot:>

# %%
liste = list(birlesim_df[birlesim_df["Age"].isnull()].index)

liste
# Out:
# [5,
#  17,
#  19,
#  26,
#  27,
#  28,
#  30,
#  31,
#  35,
#  41,
#  44,
#  45,
#  46,
#  47,
#  54,
#  63,
#  64,
#  75,
#  76,
#  81,
#  86,
#  93,
#  99,
#  105,
#  107,
#  119,
#  124,
#  126,
#  138,
#  152,
#  156,
#  163,
#  165,
#  173,
#  177,
#  181,
#  182,
#  192,
#  194,
#  209,
#  218,
#  224,
#  230,
#  235,
#  236,
#  245,
#  251,
#  255,
#  259,
#  265,
#  269,
#  272,
#  279,
#  290,
#  293,
#  295,
#  296,
#  298,
#  299,
#  301,
#  324,
#  328,
#  329,
#  340,
#  344,
#  347,
#  351,
#  352,
#  357,
#  360,
#  361,
#  368,
#  377,
#  381,
#  402,
#  403,
#  404,
#  406,
#  408,
#  413,
#  418,
#  421,
#  424,
#  437,
#  444,
#  447,
#  450,
#  452,
#  457,
#  459,
#  461,
#  463,
#  468,
#  474,
#  478,
#  483,
#  488,
#  490,
#  495,
#  500,
#  504,
#  510,
#  515,
#  517,
#  520,
#  524,
#  526,
#  531,
#  540,
#  545,
#  550,
#  553,
#  556,
#  557,
#  561,
#  566,
#  571,
#  577,
#  582,
#  586,
#  589,
#  591,
#  594,
#  595,
#  604,
#  605,
#  606,
#  622,
# ...

# %%
for i in liste:
    
    doldurulacak_age = birlesim_df[(birlesim_df["SibSp"] == birlesim_df["SibSp"].iloc[i]) & 
               (birlesim_df["Parch"] == birlesim_df["Parch"].iloc[i])&
               (birlesim_df["Pclass"] == birlesim_df["Pclass"].iloc[i])]["Age"].median()
    
    age_med = birlesim_df["Age"].median()
    
    if not np.isnan(doldurulacak_age):
        
        birlesim_df["Age"].iloc[i] = doldurulacak_age
        
    else:
        
        birlesim_df["Age"].iloc[i] = age_med
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lenovo\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\lenovo\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
birlesim_df[birlesim_df["Age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []
